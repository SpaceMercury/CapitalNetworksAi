# %%
import PySimpleGUI as sg
import random as rd

# Define the advisor function
def advisor(stock, features):
    return f"Advice for {stock}: Based on the features {', '.join(features.keys())}, here's some advice..."

# Define the chatbot function
def Chat(txt):
    return f"Chatbot response to '{txt}': This is a mock response."

# Define the function to get the best 5 stocks
def get_best_5_stocks():
    return ['AAPL', 'MSFT', 'GOOG', 'FB', 'AMZN']

# Define the function to get the best stock features
def get_the_best_stock_features_that_user_likes():
    return ['Price', 'Volume', 'Market Cap', 'P/E Ratio', 'Dividend Yield']

# Function to initialize stock features with random values
def initialize_stock_features():
    return {stock: {feature: round(rd.uniform(100, 500), 2) for feature in get_the_best_stock_features_that_user_likes()} for stock in get_best_5_stocks()}

# Function to update each stock feature by a small step
def update_stock_features():
    for stock in stocks_features:
        for feature in stocks_features[stock]:
            stocks_features[stock][feature] *= round(rd.uniform(1.00, 1.01), 2)

# Function to create stock summary text
def create_stock_summary():
    summary_text = ""
    for stock, features in stocks_features.items():
        feature_summary = ", ".join([f"{k}: {v:.2f}" for k, v in features.items()])
        summary_text += f"{stock}: {feature_summary}\n\n"
    return summary_text

# Define colors and font styles
bg_color = '#f5f5f5'
text_color = '#333333'
button_color = ('white', '#ff8c00')  # Orange color for buttons
font_large = ("Arial", 22, 'bold')
font_medium = ("Arial", 18)
font_small = ("Arial", 14)

# Window size
window_width, window_height = 1524, 968

# Layout definition
layout = [
    [sg.Text("Stock Advisor", size=(int(window_width/12), 1), font=font_large, text_color=text_color)],
    [sg.HorizontalSeparator()],
    [sg.Button(stock, size=(15, 2), font=font_medium, button_color=button_color, border_width=2) for stock in get_best_5_stocks()],
    [sg.Text("Stock Information", font=font_medium)],
    [sg.Text("", font=font_medium, key='-FEATURES-', size=(200, 10))],
    [sg.Text("", key='-ADVISOR-', size=(200, 10), font=font_small)],
    [sg.HorizontalSeparator()],
    [sg.Text("Ask Shin", font=font_large)],
    [sg.InputText(key='-CHATINPUT-', size=(200, 10), font=font_small), sg.Button('Send', size=(10, 1), font=font_medium, button_color=button_color, border_width=2)],
    [sg.Text("", key='-CHATRESPONSE-', size=(200, 10), font=font_small)],
    [sg.Column([[]], expand_x=True), sg.Button('Exit', size=(10, 2), font=font_small, button_color=('#f0f0f0', '#d9534f'), border_width=2)]
]

# Create the window
window = sg.Window('AI Networks Group Stock Advisor', layout, size=(window_width, window_height), background_color=bg_color)

# Initial stock features
stocks_features = initialize_stock_features()
window['-FEATURES-'].update(create_stock_summary())

# Event Loop
while True:
    event, values = window.read(timeout=3000)  # Update every 3000 milliseconds (3 seconds)
    if event in (None, 'Exit'):
        break

    update_stock_features()
    window['-FEATURES-'].update(create_stock_summary())

    if event in get_best_5_stocks():
        stock_features = stocks_features[event]
        advice = advisor(event, stock_features)
        window['-ADVISOR-'].update(advice)

    if event == 'Send':
        chat_response = Chat(values['-CHATINPUT-'])
        window['-CHATRESPONSE-'].update(chat_response)

# Close the window
window.close()
# Out:
# /Users/amitlevi/opt/miniconda3/envs/Qproject/lib/python3.8/site-packages/PySimpleGUI/PySimpleGUI.py:1711: UserWarning: You cannot Update element with key = -FEATURES- until the window.read() is called or finalized=True when creating window
#   warnings.warn('You cannot Update element with key = {} until the window.read() is called or finalized=True when creating window'.format(self.Key), UserWarning)
# 1   HIToolbox                           0x00007ff8184540c2 _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 30
# 2   HIToolbox                           0x00007ff81846b7e3 SetMenuBarObscured + 115
# 3   HIToolbox                           0x00007ff81847229e _ZN13HIApplication11FrontUILostEv + 34
# 4   HIToolbox                           0x00007ff81846b622 _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 508
# 5   HIToolbox                           0x00007ff818465950 _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 182
# 6   HIToolbox                           0x00007ff81842dbd2 _NotifyEventLoopObservers + 153
# 7   HIToolbox                           0x00007ff8184653e6 AcquireEventFromQueue + 494
# 8   HIToolbox                           0x00007ff8184543ec ReceiveNextEventCommon + 285
# 9   HIToolbox                           0x00007ff8184542b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 10  AppKit                              0x00007ff811c572f3 _DPSNextEvent + 909
# 11  AppKit                              0x00007ff811c56174 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 12  libtk8.6.dylib                      0x000000010ce171b2 TkMacOSXEventsCheckProc + 482
# 13  libtcl8.6.dylib                     0x000000010caeb33b Tcl_DoOneEvent + 347
# 14  _tkinter.cpython-38-darwin.so       0x000000010c12b474 _tkinter_tkapp_mainloop_impl + 228
# 15  python3.8                           0x000000010b5d9a43 method_vectorcall_FASTCALL + 307
# 16  python3.8                           0x000000010b6e34c0 _PyEval_EvalFrameDefault + 42336
# 17  python3.8                           0x000000010b5ca284 _PyFunction_Vectorcall + 1348
# 18  python3.8                           0x000000010b6e34c0 _PyEval_EvalFrameDefault + 42336
# 19  python3.8                           0x000000010b5ca284 _PyFunction_Vectorcall + 1348
# 20  python3.8                           0x000000010b5d01fd method_vectorcall + 141
# 21  python3.8                           0x000000010b6e3171 _PyEval_EvalFrameDefault + 41489
# 22  python3.8                           0x000000010b5ca284 _PyFunction_Vectorcall + 1348
# 23  python3.8                           0x000000010b5d01fd method_vectorcall + 141
# 24  python3.8                           0x000000010b6e3171 _PyEval_EvalFrameDefault + 41489
# 25  python3.8                           0x000000010b6d7178 _PyEval_EvalCodeWithName + 712
# 26  python3.8                           0x000000010b6d20a2 builtin_exec + 322
# 27  python3.8                           0x000000010b626467 cfunction_vectorcall_FASTCALL + 103
# 28  python3.8                           0x000000010b6e2823 _PyEval_EvalFrameDefault + 39107
# 29  python3.8                           0x000000010b6e377b _PyEval_EvalFrameDefault + 43035
# 30  python3.8                           0x000000010b6e377b _PyEval_EvalFrameDefault + 43035
# 31  python3.8                           0x000000010b5e2ae8 _PyGen_Send + 168
# 32  python3.8                           0x000000010b5da154 method_vectorcall_O + 308
# 33  python3.8                           0x000000010b6e34c0 _PyEval_EvalFrameDefault + 42336
# 34  python3.8                           0x000000010b5c9ee5 _PyFunction_Vectorcall + 421
# 35  python3.8                           0x000000010b6e2823 _PyEval_EvalFrameDefault + 39107
# 36  python3.8                           0x000000010b5c9ee5 _PyFunction_Vectorcall + 421
# 37  python3.8                           0x000000010b6e34c0 _PyEval_EvalFrameDefault + 42336
# 38  python3.8                           0x000000010b5ca284 _PyFunction_Vectorcall + 1348
# 39  python3.8                           0x000000010b5d02ca method_vectorcall + 346
# 40  python3.8                           0x000000010b6e761f _PyEval_EvalFrameDefault + 59071
# 41  python3.8                           0x000000010b5ca284 _PyFunction_Vectorcall + 1348
# 42  python3.8                           0x000000010b5d01fd method_vectorcall + 141
# 43  python3.8                           0x000000010b6e3171 _PyEval_EvalFrameDefault + 41489
# 44  python3.8                           0x000000010b6e377b _PyEval_EvalFrameDefault + 43035
# 45  python3.8                           0x000000010b6e377b _PyEval_EvalFrameDefault + 43035
# 46  python3.8                           0x000000010b6e377b _PyEval_EvalFrameDefault + 43035
# 47  python3.8                           0x000000010b6e377b _PyEval_EvalFrameDefault + 43035
# 48  python3.8                           0x000000010b5e2ae8 _PyGen_Send + 168
# 49  _asyncio.cpython-38-darwin.so       0x000000010bd1b43f task_step_impl + 415
# 50  _asyncio.cpython-38-darwin.so       0x000000010bd1b20e task_step + 62
# 51  _asyncio.cpython-38-darwin.so       0x000000010bd1b0d9 task_wakeup + 185
# 52  _asyncio.cpython-38-darwin.so       0x000000010bd1af7d TaskWakeupMethWrapper_call + 109
# 53  python3.8                           0x000000010b5c8b04 _PyObject_MakeTpCall + 340
# 54  python3.8                           0x000000010b7181be context_run + 62
# 55  python3.8                           0x000000010b626566 cfunction_vectorcall_FASTCALL_KEYWORDS + 102
# 56  python3.8                           0x000000010b5c94d7 PyVectorcall_Call + 455
# 57  python3.8                           0x000000010b6ec000 _PyEval_EvalFrameDefault + 77984
# 58  python3.8                           0x000000010b5c9ee5 _PyFunction_Vectorcall + 421
# 59  python3.8                           0x000000010b6e34c0 _PyEval_EvalFrameDefault + 42336
# 60  python3.8                           0x000000010b5c9ee5 _PyFunction_Vectorcall + 421
# 61  python3.8                           0x000000010b6e34c0 _PyEval_EvalFrameDefault + 42336
# 62  python3.8                           0x000000010b5c9ee5 _PyFunction_Vectorcall + 421
# 63  python3.8                           0x000000010b6e34c0 _PyEval_EvalFrameDefault + 42336
# 64  python3.8                           0x000000010b5c9ee5 _PyFunction_Vectorcall + 421
# 65  python3.8                           0x000000010b6e34c0 _PyEval_EvalFrameDefault + 42336
# 66  python3.8                           0x000000010b5c9ee5 _PyFunction_Vectorcall + 421
# 67  python3.8                           0x000000010b6e34c0 _PyEval_EvalFrameDefault + 42336
# 68  python3.8                           0x000000010b5ca284 _PyFunction_Vectorcall + 1348
# 69  python3.8                           0x000000010b5d01fd method_vectorcall + 141
# 70  python3.8                           0x000000010b6e4588 _PyEval_EvalFrameDefault + 46632
# 71  python3.8                           0x000000010b6d7178 _PyEval_EvalCodeWithName + 712
# 72  python3.8                           0x000000010b6d20a2 builtin_exec + 322
# 73  python3.8                           0x000000010b626467 cfunction_vectorcall_FASTCALL + 103
# 74  python3.8                           0x000000010b6e2823 _PyEval_EvalFrameDefault + 39107
# 75  python3.8                           0x000000010b5ca284 _PyFunction_Vectorcall + 1348
# 76  python3.8                           0x000000010b6e2823 _PyEval_EvalFrameDefault + 39107
# 77  python3.8                           0x000000010b5ca284 _PyFunction_Vectorcall + 1348
# 78  python3.8                           0x000000010b5c94d7 PyVectorcall_Call + 455
# 79  python3.8                           0x000000010b7788ce pymain_run_module + 206
# 80  python3.8                           0x000000010b77839e pymain_run_python + 238
# 81  python3.8                           0x000000010b778265 Py_RunMain + 37
# 82  python3.8                           0x000000010b598c78 main + 56
# 83  dyld                                0x00007ff80e6fa310 start + 2432
# 1   HIToolbox                           0x00007ff8184c7726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff81846b852 SetMenuBarObscured + 226
# 3   HIToolbox                           0x00007ff81846b4ca _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 164
# 4   HIToolbox                           0x00007ff818465996 _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 252
# 5   HIToolbox                           0x00007ff81842dbd2 _NotifyEventLoopObservers + 153
# 6   AppKit                              0x00007ff811e45f73 -[NSWindow(NSEventRouting) _handleMouseDownEvent:isDelayedEvent:] + 3212
# 7   AppKit                              0x00007ff811dbc58e -[NSWindow(NSEventRouting) _reallySendEvent:isDelayedEvent:] + 2595
# 8   AppKit                              0x00007ff811dbb94f -[NSWindow(NSEventRouting) sendEvent:] + 345
# 9   AppKit                              0x00007ff811db9cbe -[NSApplication(NSEvent) sendEvent:] + 358
# 10  libtk8.6.dylib                      0x000000010ce167c5 -[TKApplication(TKNotify) sendEvent:] + 53
# 11  libtk8.6.dylib                      0x000000010ce171e9 TkMacOSXEventsCheckProc + 537
# 12  libtcl8.6.dylib                     0x000000010caeb33b Tcl_DoOneEvent + 347
# 13  _tkinter.cpython-38-darwin.so       0x000000010c12b474 _tkinter_tkapp_mainloop_impl + 228
# 14  python3.8                           0x000000010b5d9a43 method_vectorcall_FASTCALL + 307
# 15  python3.8                           0x000000010b6e34c0 _PyEval_EvalFrameDefault + 42336
# 16  python3.8                           0x000000010b5ca284 _PyFunction_Vectorcall + 1348
# 17  python3.8                           0x000000010b6e34c0 _PyEval_EvalFrameDefault + 42336
# 18  python3.8                           0x000000010b5ca284 _PyFunction_Vectorcall + 1348
# 19  python3.8                           0x000000010b5d01fd method_vectorcall + 141
# 20  python3.8                           0x000000010b6e3171 _PyEval_EvalFrameDefault + 41489
# 21  python3.8                           0x000000010b5ca284 _PyFunction_Vectorcall + 1348
# 22  python3.8                           0x000000010b5d01fd method_vectorcall + 141
# 23  python3.8                           0x000000010b6e3171 _PyEval_EvalFrameDefault + 41489
# 24  python3.8                           0x000000010b6d7178 _PyEval_EvalCodeWithName + 712
# 25  python3.8                           0x000000010b6d20a2 builtin_exec + 322
# 26  python3.8                           0x000000010b626467 cfunction_vectorcall_FASTCALL + 103
# 27  python3.8                           0x000000010b6e2823 _PyEval_EvalFrameDefault + 39107
# 28  python3.8                           0x000000010b6e377b _PyEval_EvalFrameDefault + 43035
# 29  python3.8                           0x000000010b6e377b _PyEval_EvalFrameDefault + 43035
# 30  python3.8                           0x000000010b5e2ae8 _PyGen_Send + 168
# 31  python3.8                           0x000000010b5da154 method_vectorcall_O + 308
# 32  python3.8                           0x000000010b6e34c0 _PyEval_EvalFrameDefault + 42336
# 33  python3.8                           0x000000010b5c9ee5 _PyFunction_Vectorcall + 421
# 34  python3.8                           0x000000010b6e2823 _PyEval_EvalFrameDefault + 39107
# 35  python3.8                           0x000000010b5c9ee5 _PyFunction_Vectorcall + 421
# 36  python3.8                           0x000000010b6e34c0 _PyEval_EvalFrameDefault + 42336
# 37  python3.8                           0x000000010b5ca284 _PyFunction_Vectorcall + 1348
# 38  python3.8                           0x000000010b5d02ca method_vectorcall + 346
# 39  python3.8                           0x000000010b6e761f _PyEval_EvalFrameDefault + 59071
# 40  python3.8                           0x000000010b5ca284 _PyFunction_Vectorcall + 1348
# 41  python3.8                           0x000000010b5d01fd method_vectorcall + 141
# 42  python3.8                           0x000000010b6e3171 _PyEval_EvalFrameDefault + 41489
# 43  python3.8                           0x000000010b6e377b _PyEval_EvalFrameDefault + 43035
# 44  python3.8                           0x000000010b6e377b _PyEval_EvalFrameDefault + 43035
# 45  python3.8                           0x000000010b6e377b _PyEval_EvalFrameDefault + 43035
# 46  python3.8                           0x000000010b6e377b _PyEval_EvalFrameDefault + 43035
# 47  python3.8                           0x000000010b5e2ae8 _PyGen_Send + 168
# 48  _asyncio.cpython-38-darwin.so       0x000000010bd1b43f task_step_impl + 415
# 49  _asyncio.cpython-38-darwin.so       0x000000010bd1b20e task_step + 62
# 50  _asyncio.cpython-38-darwin.so       0x000000010bd1b0d9 task_wakeup + 185
# 51  _asyncio.cpython-38-darwin.so       0x000000010bd1af7d TaskWakeupMethWrapper_call + 109
# 52  python3.8                           0x000000010b5c8b04 _PyObject_MakeTpCall + 340
# 53  python3.8                           0x000000010b7181be context_run + 62
# 54  python3.8                           0x000000010b626566 cfunction_vectorcall_FASTCALL_KEYWORDS + 102
# 55  python3.8                           0x000000010b5c94d7 PyVectorcall_Call + 455
# 56  python3.8                           0x000000010b6ec000 _PyEval_EvalFrameDefault + 77984
# 57  python3.8                           0x000000010b5c9ee5 _PyFunction_Vectorcall + 421
# 58  python3.8                           0x000000010b6e34c0 _PyEval_EvalFrameDefault + 42336
# 59  python3.8                           0x000000010b5c9ee5 _PyFunction_Vectorcall + 421
# 60  python3.8                           0x000000010b6e34c0 _PyEval_EvalFrameDefault + 42336
# 61  python3.8                           0x000000010b5c9ee5 _PyFunction_Vectorcall + 421
# 62  python3.8                           0x000000010b6e34c0 _PyEval_EvalFrameDefault + 42336
# 63  python3.8                           0x000000010b5c9ee5 _PyFunction_Vectorcall + 421
# 64  python3.8                           0x000000010b6e34c0 _PyEval_EvalFrameDefault + 42336
# 65  python3.8                           0x000000010b5c9ee5 _PyFunction_Vectorcall + 421
# 66  python3.8                           0x000000010b6e34c0 _PyEval_EvalFrameDefault + 42336
# 67  python3.8                           0x000000010b5ca284 _PyFunction_Vectorcall + 1348
# 68  python3.8                           0x000000010b5d01fd method_vectorcall + 141
# 69  python3.8                           0x000000010b6e4588 _PyEval_EvalFrameDefault + 46632
# 70  python3.8                           0x000000010b6d7178 _PyEval_EvalCodeWithName + 712
# 71  python3.8                           0x000000010b6d20a2 builtin_exec + 322
# 72  python3.8                           0x000000010b626467 cfunction_vectorcall_FASTCALL + 103
# 73  python3.8                           0x000000010b6e2823 _PyEval_EvalFrameDefault + 39107
# 74  python3.8                           0x000000010b5ca284 _PyFunction_Vectorcall + 1348
# 75  python3.8                           0x000000010b6e2823 _PyEval_EvalFrameDefault + 39107
# 76  python3.8                           0x000000010b5ca284 _PyFunction_Vectorcall + 1348
# 77  python3.8                           0x000000010b5c94d7 PyVectorcall_Call + 455
# 78  python3.8                           0x000000010b7788ce pymain_run_module + 206
# 79  python3.8                           0x000000010b77839e pymain_run_python + 238
# 80  python3.8                           0x000000010b778265 Py_RunMain + 37
# 81  python3.8                           0x000000010b598c78 main + 56
# 82  dyld                                0x00007ff80e6fa310 start + 2432
